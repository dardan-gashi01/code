# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **LOADING THE IMAGES AND LABELS**

# %%
import os

GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Colab Notebooks/CW_Folder_UG/CW_Folder_UG' 
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['test_functions.ipynb', '.DS_Store', 'CW_Dataset.zip', 'Code', 'Models', 'Personal_Dataset']

# %%
# !pip install opencv-python==4.5.5.64
# Out:
# Collecting opencv-python==4.5.5.64
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      |████████████████████████████████| 60.5 MB 102 kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python==4.5.5.64) (1.21.5)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed opencv-python-4.5.5.64

# %%
# !pip show opencv-python
# Out:
# Name: opencv-python
# Version: 4.5.5.64
# Summary: Wrapper package for OpenCV python bindings.
# Home-page: https://github.com/skvark/opencv-python
# Author: None
# Author-email: None
# License: MIT
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: numpy
# Required-by: imgaug, dopamine-rl, albumentations

# %%
from sklearn import svm, metrics
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
from skimage import img_as_ubyte, io, color
from sklearn.model_selection import train_test_split
from sklearn import svm, metrics
from collections import Counter
import cv2
from sklearn.cluster import MiniBatchKMeans

# %%
zip_path = os.path.join(GOOGLE_DRIVE_PATH, 'CW_Dataset.zip')

# !cp '{zip_path}' .

# !yes|unzip -q CW_Dataset.zip

# !rm CW_Dataset.zip
# Out:
# replace test/test_0288_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0828_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1505_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0317_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1055_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0647_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2986_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1923_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0591_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2326_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1383_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2676_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_3064_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2819_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2714_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2244_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1841_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1137_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2192_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0725_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1467_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0275_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0858_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0367_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1575_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2080_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0637_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1025_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2356_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_3014_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2606_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1953_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2799_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2869_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1831_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2894_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2764_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1291_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0483_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2234_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1588_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0755_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1147_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0205_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1417_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0964_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2573_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1086_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_2023_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0694_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1449_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1119_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_0542_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: replace test/test_1350_aligned.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: repl ...

# %% [markdown]
# creating a labels list and an images list so we cant get out trainig data

# %%
def import_images(path):
  images = []

  file_name = [file for file in sorted(os.listdir(os.path.join(path))) if file.endswith('.jpg')]
  for file in file_name:
    images.append(plt.imread(os.path.join(path, file)))

  return images;

# %%
X = import_images('train')

# %%
def import_labels(path):
  label= []
  with open ((os.path.join(path)), "r") as myfile:
    data = myfile.read().splitlines()
    for i in data:
      x,y = i.split(" ")
      label.append(y)
  return label

# %%
y = import_labels('labels/list_label_train.txt')

# %%
Counter(y)
# Out:
# Counter({'1': 1290,
#          '2': 281,
#          '3': 717,
#          '4': 4772,
#          '5': 1982,
#          '6': 705,
#          '7': 2524})

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=True, stratify=y)

# %%
X2 = np.array(X)

# %%
X2.shape
# Out:
# (12271, 100, 100, 3)

# %%
fig, axes = plt.subplots(nrows=2, ncols=5, figsize = (10,5), sharex=True, sharey = True)
ax = axes.ravel()

for i in range(10):
  ax[i].imshow(X_train[i], cmap='gray')
  ax[i].set_title(f'Label: {y_train[i]}')
  
fig.tight_layout()
plt.show()

# %% [markdown]
# ***SIFT***

# %%
# Initiate SIFT detector
sift = cv2.SIFT_create()

# Create empty lists for feature descriptors and labels
des_list = []
y_train_list = []

fig, ax = plt.subplots(1, 4, figsize=(10, 8), sharey=True)

for i in range(len(X_train)):
    # Identify keypoints and extract descriptors with SIFT
    img = img_as_ubyte(color.rgb2gray(X_train[i]))
    kp, des = sift.detectAndCompute(img, None)

    # Show results for first 4 images
    if i<4:
        img_with_SIFT = cv2.drawKeypoints(img, kp, img)
        ax[i].imshow(img_with_SIFT)
        ax[i].set_axis_off()

    # Append list of descriptors and label to respective lists
    if des is not None:
        des_list.append(des)
        y_train_list.append(y_train[i])

fig.tight_layout()
plt.show()

# Convert to array for easier handling
des_array = np.vstack(des_list)

# %%
k = len(np.unique(y_train)) * 10

# Use MiniBatchKMeans for faster computation and lower memory usage
batch_size = des_array.shape[0] // 4
kmeans = MiniBatchKMeans(n_clusters=k, batch_size=batch_size).fit(des_array)

# %%
# Convert descriptors into histograms of codewords for each image
hist_list = []
idx_list = []

for des in des_list:
    hist = np.zeros(k)

    idx = kmeans.predict(des)
    idx_list.append(idx)
    for j in idx:
        hist[j] = hist[j] + (1 / len(des))
    hist_list.append(hist)

hist_array = np.vstack(hist_list)

# %% [markdown]
# **SVM + SIFT**

# %%
# Create a classifier: a support vector classifier
classifier = svm.SVC(kernel='rbf')

# We learn the digits on the first half of the digits
classifier.fit(hist_array, y_train_list)
# Out:
# SVC()

# %%
hist_list = []

for i in range(len(X_test)):
    img = img_as_ubyte(color.rgb2gray(X_test[i]))
    kp, des = sift.detectAndCompute(img, None)

    if des is not None:
        hist = np.zeros(k)

        idx = kmeans.predict(des)

        for j in idx:
            hist[j] = hist[j] + (1 / len(des))

        # hist = scale.transform(hist.reshape(1, -1))
        hist_list.append(hist)

    else:
        hist_list.append(None)

# Remove potential cases of images with no descriptors
idx_not_empty = [i for i, x in enumerate(hist_list) if x is not None]
hist_list = [hist_list[i] for i in idx_not_empty]
y_test = [y_test[i] for i in idx_not_empty]
hist_array = np.vstack(hist_list)

# %%
y_pred = classifier.predict(hist_array).tolist()

# %%
fig, axes = plt.subplots(2, 5, figsize=(14, 7), sharex=True, sharey=True)
ax = axes.ravel()

for i in range(10):
    ax[i].imshow(X_test[i])
    ax[i].set_title(f'Label: {y_test[i]} \n Prediction: {y_pred[i]}')
    ax[i].set_axis_off()
fig.tight_layout()
plt.show()

# %%
print(f"""Classification report for classifier {classifier}:
      {metrics.classification_report(y_test, y_pred)}\n""")
# Out:
# Classification report for classifier SVC():
#                     precision    recall  f1-score   support
#
#            1       0.38      0.09      0.15       258
#            2       0.00      0.00      0.00        55
#            3       0.00      0.00      0.00       143
#            4       0.44      0.85      0.58       954
#            5       0.32      0.02      0.04       397
#            6       0.00      0.00      0.00       141
#            7       0.35      0.35      0.35       504
#
#     accuracy                           0.42      2452
#    macro avg       0.21      0.19      0.16      2452
# weighted avg       0.33      0.42      0.32      2452
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
